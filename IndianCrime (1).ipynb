# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('crime_dataset_india.csv')
df
# Out:
#        Report Number     Date Reported Date of Occurrence Time of Occurrence  \
# 0                  1  02-01-2020 00:00   01-01-2020 00:00   01-01-2020 01:11
# 1                  2  01-01-2020 19:00   01-01-2020 01:00   01-01-2020 06:26
# 2                  3  02-01-2020 05:00   01-01-2020 02:00   01-01-2020 14:30
# 3                  4  01-01-2020 05:00   01-01-2020 03:00   01-01-2020 14:46
# 4                  5  01-01-2020 21:00   01-01-2020 04:00   01-01-2020 16:51
# ...              ...               ...                ...                ...
# 40155          40156  01-08-2024 16:00   07-31-2024 03:00   31-07-2024 05:05
# 40156          40157  31-07-2024 14:00   07-31-2024 04:00   31-07-2024 04:14
# 40157          40158  02-08-2024 03:00   07-31-2024 05:00   31-07-2024 21:33
# 40158          40159  01-08-2024 19:00   07-31-2024 06:00   31-07-2024 11:05
# 40159          40160  31-07-2024 17:00   07-31-2024 07:00   31-07-2024 17:19
#
# ...

# %%
df.head()
# Out:
#    Report Number     Date Reported Date of Occurrence Time of Occurrence  \
# 0              1  02-01-2020 00:00   01-01-2020 00:00   01-01-2020 01:11
# 1              2  01-01-2020 19:00   01-01-2020 01:00   01-01-2020 06:26
# 2              3  02-01-2020 05:00   01-01-2020 02:00   01-01-2020 14:30
# 3              4  01-01-2020 05:00   01-01-2020 03:00   01-01-2020 14:46
# 4              5  01-01-2020 21:00   01-01-2020 04:00   01-01-2020 16:51
#
#         City  Crime Code Crime Description  Victim Age Victim Gender  \
# 0  Ahmedabad         576    IDENTITY THEFT          16             M
# 1    Chennai         128          HOMICIDE          37             M
# 2   Ludhiana         271        KIDNAPPING          48             F
# 3       Pune         170          BURGLARY          49             F
# 4       Pune         421         VANDALISM          30             F
#
#     Weapon Used   Crime Domain  Police Deployed Case Closed  Date Case Closed
# ...

# %%
df.shape
# Out:
# (40160, 14)

# %%
df.columns
# Out:
# Index(['Report Number', 'Date Reported', 'Date of Occurrence',
#        'Time of Occurrence', 'City', 'Crime Code', 'Crime Description',
#        'Victim Age', 'Victim Gender', 'Weapon Used', 'Crime Domain',
#        'Police Deployed', 'Case Closed', 'Date Case Closed'],
#       dtype='object')

# %%
df.isnull()
# Out:
#        Report Number  Date Reported  Date of Occurrence  Time of Occurrence  \
# 0              False          False               False               False
# 1              False          False               False               False
# 2              False          False               False               False
# 3              False          False               False               False
# 4              False          False               False               False
# ...              ...            ...                 ...                 ...
# 40155          False          False               False               False
# 40156          False          False               False               False
# 40157          False          False               False               False
# 40158          False          False               False               False
# 40159          False          False               False               False
#
# ...

# %%
features = ['Report Number', 'Date Reported', 'Date of Occurrence',
       'Time of Occurrence', 'City', 'Crime Code', 'Crime Description',
       'Victim Age', 'Victim Gender', 'Weapon Used', 'Crime Domain',
       'Police Deployed', 'Case Closed', 'Date Case Closed']
for feature in features:
    null_check = pd.isnull(df[feature])
    print(df[null_check])
# Out:
# Empty DataFrame
# Columns: [Report Number, Date Reported, Date of Occurrence, Time of Occurrence, City, Crime Code, Crime Description, Victim Age, Victim Gender, Weapon Used, Crime Domain, Police Deployed, Case Closed, Date Case Closed]
# Index: []
# Empty DataFrame
# Columns: [Report Number, Date Reported, Date of Occurrence, Time of Occurrence, City, Crime Code, Crime Description, Victim Age, Victim Gender, Weapon Used, Crime Domain, Police Deployed, Case Closed, Date Case Closed]
# Index: []
# Empty DataFrame
# Columns: [Report Number, Date Reported, Date of Occurrence, Time of Occurrence, City, Crime Code, Crime Description, Victim Age, Victim Gender, Weapon Used, Crime Domain, Police Deployed, Case Closed, Date Case Closed]
# Index: []
# Empty DataFrame
# Columns: [Report Number, Date Reported, Date of Occurrence, Time of Occurrence, City, Crime Code, Crime Description, Victim Age, Victim Gender, Weapon Used, Crime Domain, Police Deployed, Case Closed, Date Case Closed]
# ...

# %%
df ['City'].unique()
# Out:
# array(['Ahmedabad', 'Chennai', 'Ludhiana', 'Pune', 'Delhi', 'Mumbai',
#        'Surat', 'Visakhapatnam', 'Bangalore', 'Kolkata', 'Ghaziabad',
#        'Hyderabad', 'Jaipur', 'Lucknow', 'Bhopal', 'Patna', 'Kanpur',
#        'Varanasi', 'Nagpur', 'Meerut', 'Thane', 'Indore', 'Rajkot',
#        'Vasai', 'Agra', 'Kalyan', 'Nashik', 'Srinagar', 'Faridabad'],
#       dtype=object)

# %%
df_city = df.groupby('City').size().reset_index(name = 'Numbers')
df_city
# Out:
#              City  Numbers
# 0            Agra      764
# 1       Ahmedabad     1817
# 2       Bangalore     3588
# 3          Bhopal      690
# 4         Chennai     2493
# 5           Delhi     5400
# 6       Faridabad      354
# 7       Ghaziabad      704
# 8       Hyderabad     2881
# 9          Indore      699
# 10         Jaipur     1479
# 11         Kalyan      355
# 12         Kanpur     1112
# 13        Kolkata     2518
# 14        Lucknow     1456
# 15       Ludhiana      761
# 16         Meerut      395
# 17         Mumbai     4415
# 18         Nagpur     1053
# 19         Nashik      366
# 20          Patna      695
# 21           Pune     2212
# 22         Rajkot      320
# 23       Srinagar      371
# 24          Surat     1111
# 25          Thane      706
# 26       Varanasi      355
# 27          Vasai      362
# 28  Visakhapatnam      728

# %%
plt.figure(figsize = (20, 5))
plt.xlabel('City')
plt.title('Arrests In City')
plt.ylabel('Numbers')
x = df_city['City']
y = df_city['Numbers']
plt.bar(x, y)
plt.grid(which = 'both', linestyle = ':')
plt.savefig('City.jpg', dpi = 480)

# %%
sns.displot(df['City'], kde = True, bins = 50)

# %%
df ['Victim Age'].unique()
# Out:
# array([16, 37, 48, 49, 30, 64, 78, 41, 29, 71, 26, 36, 32, 77, 51, 61, 11,
#        62, 50, 69, 18, 60, 33, 73, 24, 34, 22, 28, 42, 40, 44, 67, 47, 38,
#        54, 75, 70, 53, 56, 19, 58, 45, 25, 59, 31, 35, 52, 39, 72, 10, 74,
#        13, 12, 21, 55, 15, 43, 14, 57, 79, 17, 46, 23, 27, 66, 63, 68, 65,
#        76, 20], dtype=int64)

# %%
df_age = df.groupby('Victim Age').size().reset_index(name = 'Numbers')
df_age
# Out:
#     Victim Age  Numbers
# 0           10      571
# 1           11      606
# 2           12      534
# 3           13      574
# 4           14      542
# ..         ...      ...
# 65          75      565
# 66          76      607
# 67          77      555
# 68          78      596
# 69          79      597
#
# [70 rows x 2 columns]

# %%
plt.figure(figsize = (20, 5))
plt.xlabel('Victim Age')
plt.title('Arrests by Age')
plt.ylabel('Numbers')
x = df_age['Victim Age']
y = df_age['Numbers']
plt.bar(x, y)
plt.grid(which = 'both', linestyle = ':')
plt.savefig('Victim Age.jpg', dpi = 480)

# %%
sns.displot(df['Victim Age'], kde = True, bins = 50)

# %%
df ['Victim Gender'].unique()
# Out:
# array(['M', 'F', 'X'], dtype=object)

# %%
df_sex = df.groupby('Victim Gender').size().reset_index(name = 'Numbers')
df_sex
# Out:
#   Victim Gender  Numbers
# 0             F    22423
# 1             M    13405
# 2             X     4332

# %%
plt.figure(figsize = (10, 5))
plt.xlabel('Victim Gender')
plt.title('Arrests by Gender')
plt.ylabel('Numbers')
x = df_sex['Victim Gender']
y = df_sex['Numbers']
plt.bar(x, y)
plt.grid(which = 'both', linestyle = ':')
plt.savefig('Victim Gender.jpg', dpi = 480)

# %%
sns.displot(df['Victim Gender'], kde = True, bins = 50)

# %%
df ['Crime Domain'].unique()
# Out:
# array(['Violent Crime', 'Other Crime', 'Fire Accident',
#        'Traffic Fatality'], dtype=object)

# %%
df_domain = df.groupby('Crime Domain').size().reset_index(name = 'Numbers')
df_domain
# Out:
#        Crime Domain  Numbers
# 0     Fire Accident     3825
# 1       Other Crime    22948
# 2  Traffic Fatality     1915
# 3     Violent Crime    11472

# %%
plt.figure(figsize = (10, 5))
plt.xlabel('Crime Domain')
plt.title('Arrests by Crime Domain')
plt.ylabel('Numbers')
x = df_domain['Crime Domain']
y = df_domain['Numbers']
plt.bar(x, y)
plt.grid(which = 'both', linestyle = ':')
plt.savefig('Crime Domain.jpg', dpi = 480)

# %%
sns.displot(df['Crime Domain'], kde = True, bins = 50)

# %%
df ['Crime Description'].unique()
# Out:
# array(['IDENTITY THEFT', 'HOMICIDE', 'KIDNAPPING', 'BURGLARY',
#        'VANDALISM', 'ASSAULT', 'VEHICLE - STOLEN', 'COUNTERFEITING',
#        'EXTORTION', 'PUBLIC INTOXICATION', 'FRAUD', 'SEXUAL ASSAULT',
#        'DRUG OFFENSE', 'ARSON', 'CYBERCRIME', 'TRAFFIC VIOLATION',
#        'SHOPLIFTING', 'ILLEGAL POSSESSION', 'FIREARM OFFENSE', 'ROBBERY',
#        'DOMESTIC VIOLENCE'], dtype=object)

# %%
df_des = df.groupby('Crime Description').size().reset_index(name = 'Numbers')
df_des
# Out:
#       Crime Description  Numbers
# 0                 ARSON     1894
# 1               ASSAULT     1915
# 2              BURGLARY     1980
# 3        COUNTERFEITING     1871
# 4            CYBERCRIME     1899
# 5     DOMESTIC VIOLENCE     1932
# 6          DRUG OFFENSE     1890
# 7             EXTORTION     1873
# 8       FIREARM OFFENSE     1931
# 9                 FRAUD     1965
# 10             HOMICIDE     1909
# 11       IDENTITY THEFT     1918
# 12   ILLEGAL POSSESSION     1895
# 13           KIDNAPPING     1920
# 14  PUBLIC INTOXICATION     1912
# 15              ROBBERY     1928
# 16       SEXUAL ASSAULT     1917
# 17          SHOPLIFTING     1859
# 18    TRAFFIC VIOLATION     1915
# 19            VANDALISM     1975
# 20     VEHICLE - STOLEN     1862

# %%
plt.figure(figsize = (10, 5))
plt.xlabel('Crime Description')
plt.title('Arrests by Crime Description')
plt.ylabel('Numbers')
x = df_des['Crime Description']
y = df_des['Numbers']
plt.bar(x, y)
plt.grid(which = 'both', linestyle = ':')
plt.savefig('Crime Description.jpg', dpi = 480)

# %%
sns.displot(df['Crime Description'], kde = True, bins = 10)

# %%
df_min = df['Crime Domain'].min()
df_max = df['Crime Domain'].max()
print(df_min, df_max)
# Out:
# Fire Accident Violent Crime

# %%
sns.boxplot(df['Crime Domain'])
# Out:
# <Axes: ylabel='Crime Domain'>

# %%
q_1 = df['Victim Age'].quantile(0.25)
q_3 = df['Victim Age'].quantile(0.75)
iqr = q_3 - q_1
lower = q_1 - 1.5 * iqr
upper = q_3 + 1.5 * iqr

# %%
upper_array = np.where(df['Victim Age'] >= upper)[0]
lower_array = np.where(df['Victim Age'] <= lower)[0]

# %%
df.drop(index = upper_array, inplace = True)
df.drop(index = lower_array, inplace = True)

# %%
df.shape
# Out:
# (40160, 14)
